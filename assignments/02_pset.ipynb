# %% [markdown]
# # Лабораторная работа 2
# ## Контейнеры

# %% [markdown]
# ### Задание 1
# - Создайте список;
# ```Python
# t1_l = [0, 1, 4, 2, 0, 2, 3, 4]
# ```
# - Создайте новый список, в котором бы остались только уникальные элементы `t1_l` (т.е. никакие элементы в нём не повторялись несколько раз), выведите его на печать;
# - Создайте новый список из элементов `t1_l` отсортированных по возрастанию, напечатайте его;
# - Создайте новый список `t1_lsq`, заполните его элементами `t1_l` возведёнными во вторую степень;
# - Сосчитайте и напечатайте сумму всех элементов `t1_lsq`.

# %%
# Здесь будет ваш код

# %% [markdown]
# ### Задание 2
# - Создайте список `t2_l`. С помощью цикла `while` заполните его остатками от деления на 5 чисел с 0 до 20 (включая 0 и 20) в порядке следования делимых чисел (имеется ввиду 0, 1, 2, 3, 4, 0, 1, 2, …);
# - Создайте список `t2_l_odd` из нечётных элементов `t2_l`;
# - Напечатайте `t2_l`, `t2_l_odd`.

# %%
# Здесь будет ваш код

# %% [markdown]
# ### Задание 3
# - Создайте пустой словарь `t3_d`
# - Заполните его так, чтобы
#   - Ключи были в диапазоне 0…20 (включая 0 и 20)
#   - Каждое значение было равнялось ключу + 1, т.е. `{0: 1, 1: 2, 2:3, …}`
# - Из `t3_d` сделайте новый словарь `t3_d_inv`, в котором ключи и значения `t3_d` поменяны местами, т.е. `{1: 0, 2: 1, 3:2, …}`

# %%
# Здесь будет ваш код

# %% [markdown]
# ### Задание 4
# - Дано число `t4_a = 6793049`
# - Разбейте это число на цифры и внесите в список `t4_l`
# - Присвойте переменным `t4_mn` и `t4_mx` значение наименьшей и наибольшей цифр из списка `t4_l` соответственно;
# - Выведите на экран список `t4_l`, `t4_mn`, `t4_mx`.

# %%
# Здесь будет ваш код

# %% [markdown]
# ### Задание 5
# - Создайте список из 4 элементов
# ```Python
# t6_edges = [[1, 2, 4], [3, 4, 5], [3, 3, 6], [3, 4, 6]]
# ```
# Это список 3-элементных списков. В каждый 3-элементный список записаны длины сторон треугольника. Обратите внимание, каждый 3-элементный список отсортирован по возрастанию.
# - Из списка `t6_edges` создайте список `t6_triangle` содержащий набор переменных типа `bool`, отвечающих на вопрос "возможно ли существование треугольника с такими длинами сторон?"
# - Из списка `t6_edges` создайте список `t6_pifagor` содержащий набор переменных типа `bool`, отвечающих на вопрос "является ли данный треугольник прямоугольным?"
# - Выведите `t6_triangle`, `t6_pifagor` на печать.

# %%
# Здесь будет ваш код
