# %% [markdown]
# # Лабораторная работа 2
# ## Контейнеры

# %% [markdown]
# #### Результаты этой лабораторной работы будут проверяться автоматически. Пожалуйста, выполняйте задания в точности так как указано, создавайте переменные с указанными в задании именами.

# %% [markdown]
# ### Задание 1
# - Создайте список;
# ```Python
# t1_l = [0, 1, 4, 2, 0, 2, 3, 4]
# ```
# - Сделайте так, чтобы в списке `t1_l` остались только уникальные элементы (т.е. никакие элементы в нём не повторялись несколько раз);
# - Отсортируйте элементы `t1_l` по возрастанию;
# - С помощью цикла `for` заполните `t1_lsq` элементами списка `t1_l` возведёнными во вторую степень
# - С помощью цикла `for` (или стандартных функций Python, на ваше усмотрение) запишите в переменную `t1_lsq_sum` сумму всех элементов `t1_lsq`

# %%
# Здесь будет ваш код

# %% [markdown]
# ### Задание 2
# - Создайте список `t2_l`
# - С помощью цикла `while` заполните список `t2_l` остатками от деления на 5 чисел с 0 до 20 (включая 0 и 20) в порядке следования делимых чисел (имеется ввиду 0, 1, 2, 3, 4, 0, 1, 2, …)
# - Создайте список `t2_l_odd` из нечётных элементов `t2_l`

# %%
# Здесь будет ваш код

# %% [markdown]
# ### Задание 3
# - Создайте пустой словарь `t3_d`
# - Заполните его так, чтобы
#   - Ключи были в диапазоне 0…20 (включая 0 и 20)
#   - Каждое значение было равно ключ + 1, т.е. `{0: 1, 1: 2, 2:3, …}`
# - Из `t3_d` сделайте новый словарь `t3_d_inv`, в котором ключи и значения `t3_d` поменяны местами, т.е. `{1: 0, 2: 1, 3:2, …}`

# %%
# Здесь будет ваш код

# %% [markdown]
# ### Задание 4
# - Дано переменную `t4_a = 6793049`
# - Разбейте число на цифры и внесите в список `t4_l`
# - Присвойте переменным `t4_mn` и `t4_mx` значение наименьшей и наибольшей цифр из списка `t4_l` соответственно;
# - Выведите на экран список `t4_l`, `t4_mn`, `t4_mx`.

# %%
# Здесь будет ваш код

# %% [markdown]
# ### Задание 5
# - Используя цикл `while`, напишите программу, выводящую на экран каждый шаг вычисления геометрической прогрессии вида `A(n+1)=A(n)/8` (брать только целую часть);
# - Исходное число `t5_A = 12345`, число шагов `n == 10`, отсчитывается с `1`;
# - После прохождения цикола значение перeменной должно быть `t5_A == 12`

# %%
# Здесь будет ваш код

# %% [markdown]
# ### Задание 6
# - Создайте список из 4 элементов
# ```Python
# t6_edges = [[1, 2, 4], [3, 4, 5], [3, 3, 6], [3, 4, 6]]
# ```
# Это список 3-элементных списков. В каждый 3-элементный список записаны длины сторон треугольника. Обратите внимание, каждый 3-элементный список отсортирован по возрастанию.
# - Из списка `t6_edges` создайте список `t6_triangle` содержащий набор переменных типа `bool`, отвечающих на вопрос "возможно ли существование треугольника с такими длинами сторон?"
# - Из списка `t6_edges` создайте список `t6_pifagor` содержащий набор переменных типа `bool`, отвечающих на вопрос "является ли данный треугольник прямоугольным?"

# %%
# Здесь будет ваш код

# %% [markdown]
# ### Задание 7
# - Создайте список `t7_l` содержащий первые 10 чисел последовательности Фибоначчи
# - Создайте список `t7_l_sqr`, содержащий квадраты данных чисел
# - Выведите список `t7_l_sqrt` на экран
